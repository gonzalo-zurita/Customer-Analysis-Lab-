# %%
import pandas as pd

marketing_customer_analysis = pd.read_csv('marketing_customer_analysis.csv')
marketing_customer_analysis.head()
# Out:
#    Unnamed: 0  unnamed: 0 customer       state  customer lifetime value  \
# 0           0           0  DK49336     Arizona              4809.216960
# 1           1           1  KX64629  California              2228.525238
# 2           2           2  LZ68649  Washington             14947.917300
# 3           3           3  XL78013      Oregon             22332.439460
# 4           4           4  QA50777      Oregon              9025.067525
#
#   response  coverage education effective to date employmentstatus  ...  \
# 0       No     Basic   College        2011-02-18         Employed  ...
# 1       No     Basic   College        2011-01-18       Unemployed  ...
# 2       No     Basic  Bachelor        2011-02-10         Employed  ...
# 3      Yes  Extended   College        2011-01-11         Employed  ...
# 4       No   Premium  Bachelor        2011-01-17    Medical Leave  ...
#
#   number of open complaints  number of policies     policy type        policy  \
# ...

# %%
marketing_data = marketing_customer_analysis.drop(['Unnamed: 0', 'unnamed: 0'], axis=1)
marketing_data.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0        2011-02-18         Employed      M   48029  ...
# 1        2011-01-18       Unemployed      F       0  ...
# 2        2011-02-10         Employed      M   22139  ...
# 3        2011-01-11         Employed      M   49078  ...
# 4        2011-01-17    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                  0.000000                  9  Corporate Auto  Corporate L3
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marketing_data.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
#  numeric data into dataframe called 'numerical_data'

# %%
marketing_data._get_numeric_data()
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                     7.000000                             52
# 1                     3.000000                             26
# ...

# %%
numeric_data = marketing_data._get_numeric_data()
numeric_data
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                     7.000000                             52
# 1                     3.000000                             26
# ...

# %%
numeric_data.shape
# Out:
# (10910, 9)

# %%
#  categorical data into dataframe called 'categorical_data'

# %%
marketing_data.select_dtypes('object')
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College        2011-02-18
# 1      KX64629  California       No     Basic   College        2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor        2011-01-17
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        2011-01-19
# 10906  KX53892      Oregon       No     Basic   College        2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor        2011-02-06
# 10908  WA60547  California       No   Premium   College        2011-02-13
# 10909  IV32877  California       No     Basic  Bachelor        2011-01-08
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
categorical_data = marketing_data.select_dtypes('object')
categorical_data
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College        2011-02-18
# 1      KX64629  California       No     Basic   College        2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor        2011-01-17
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        2011-01-19
# 10906  KX53892      Oregon       No     Basic   College        2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor        2011-02-06
# 10908  WA60547  California       No   Premium   College        2011-02-13
# 10909  IV32877  California       No     Basic  Bachelor        2011-01-08
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
categorical_data.shape
# Out:
# (10910, 16)

# %%
# Cheking Multicolinearity and correlation matrix

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
lm = linear_model.LinearRegression()

# %%
y = numeric_data['total claim amount']
X = numeric_data[['monthly premium auto']]

# %%
model = lm.fit(X,y)
print(lm.intercept_)
print(lm.coef_)
plt.show()
# Out:
# -64.60814048056363
# [5.35963084]

# %%
# correlation matrix map

# %%
numeric_data
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                     7.000000                             52
# 1                     3.000000                             26
# ...

# %%
# Correlations Matrix for numeric data

correlations_matrix = numeric_data.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
# there is correlation (0.63) between total claim ammount and monthly premium auto.
# there is also correlation (0.23) between total customer lifetime value and monthly premium auto.

#there is not enough correlation between features (>0.9), therefore there is no need to drop features
# there is no multicoliniarity

# %%
lm.score(X,y)
# Out:
# 0.3991694213983369

# %%
# check the normality of the numerical variables visually

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Distribution plot with seaborns

sns.displot(numeric_data['total claim amount'])
plt.show()

# %%
sns.displot(numeric_data['customer lifetime value'])
plt.show()

# %%
sns.displot(numeric_data['income'])
plt.show()

# %%
sns.displot(numeric_data['months since last claim'])
plt.show()

# %%
sns.displot(numeric_data['months since policy inception'])
plt.show()

# %%
sns.displot(numeric_data['number of open complaints'])
plt.show()

# %%
sns.displot(numeric_data['number of policies'])
plt.show()

# %%
# Distribution plot with Matplotlib

numeric_data['total claim amount'].hist()
plt.show()

# %%
numeric_data['customer lifetime value'].hist()
plt.show()

# %%
numeric_data['income'].hist()
plt.show()

# %%
numeric_data['months since last claim'].hist()
plt.show()

# %%
numeric_data['months since policy inception'].hist()
plt.show()

# %%
numeric_data['number of open complaints'].hist()
plt.show()

# %%
numeric_data['number of policies'].hist()
plt.show()

# %%
# Most of the numerical elements don't have a normal distribution becaue there is a lo of data gathered at lower values, and not many at the higher values
# to solve this, you can remove the outliers
